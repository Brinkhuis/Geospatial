# %% [markdown]
# # Overzicht shapefiles

# %%
# import modules and version info
import sys
print(f'python     {sys.version_info.major}.{sys.version_info.minor}.{sys.version_info.micro}')

import pandas as pd
print(f'pandas     {pd.__version__}')

import geopandas as gpd
print(f'geopandas  {gpd.__version__}')

import matplotlib.pyplot as plt
print(f'matplotlib {sys.modules["matplotlib"].__version__}')
      
from shapely.geometry import Point, Polygon
print(f'shapely    {sys.modules["shapely"].__version__}')
# Out:
# python     3.6.6
# pandas     0.23.4
# geopandas  0.4.0
# matplotlib 2.2.2
# shapely    1.6.4.post2

# %% [markdown]
# ### 2018-Imergis_provinciegrenzen_kustlijn-shp

# %%
file = '../shapefiles/Imergis/2018-Imergis_provinciegrenzen_kustlijn-shp/2018-Imergis_provinciegrenzen_kustlijn.shp'
data = gpd.read_file(file)

# %%
data.head()
# Out:
#    id     provincien                                           geometry
# 0   1  Noord-Holland  (POLYGON ((140119.7695681169 557037.3933508723...
# 1   2      Groningen  (POLYGON ((214930.61 595370.8100000001, 214743...
# 2   3     Overijssel  (POLYGON ((204118.188 494995.02, 204081.241 49...
# 3   4        Zeeland  (POLYGON ((48116.21645152492 419985.8556412539...
# 4   5      Friesland  (POLYGON ((208479.1558739071 603048.130863155,...

# %%
data.shape
# Out:
# (12, 3)

# %%
f, ax = plt.subplots(1, figsize=(10, 12))
ax = data.plot(ax=ax, edgecolor='white', color='steelblue', linewidth=1)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 2018-Imergis_gemeentegrenzen_kustlijn-shp

# %%
file = '../shapefiles/Imergis/2018-Imergis_gemeentegrenzen_kustlijn-shp/2018-Imergis_gemeentegrenzen_kustlijn.shp'
data = gpd.read_file(file)

# %%
data.shape
# Out:
# (380, 4)

# %%
data.head()
# Out:
#    id  code      gemeentena                                           geometry
# 0   1  0584  Oud-Beijerland  POLYGON ((86155.55100000001 425626.193, 86155....
# 1  18  0160      Hardenberg  POLYGON ((235753.945 520891.056, 235788.817 52...
# 2  19  0327         Leusden  POLYGON ((156842.831 462252.598, 156843.065 46...
# 3  20  1931  Krimpenerwaard  POLYGON ((104334.072 443036.486, 104342.974 44...
# 4  21  1701      Westerveld  POLYGON ((207869.464 536733.644, 207862.002 53...

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 4 columns):
# id            380 non-null int64
# code          380 non-null object
# gemeentena    380 non-null object
# geometry      380 non-null object
# dtypes: int64(1), object(3)
# memory usage: 12.0+ KB

# %%
f, ax = plt.subplots(1, figsize=(10, 12))
ax = data.plot(ax=ax, edgecolor='white', color='steelblue', linewidth=0.2)
plt.axis('off')
plt.show()

# %% [markdown]
# ### BAG-Woonplaatsgrenzen.shp

# %%
file = '../shapefiles/bag/BAG-Woonplaatsgrenzen-shp/BAG-Woonplaatsgrenzen.shp'
data = gpd.read_file(file)

# %%
data.shape
# Out:
# (2500, 17)

# %%
data.head()
# Out:
#    id identifica gemcode      gemnaam                 status         naam  \
# 0   0       1000    0873  Woensdrecht  Woonplaats aangewezen  Hoogerheide
# 1   1       1001    0873  Woensdrecht  Woonplaats aangewezen   Huijbergen
# 2  15       1014    0342        Soest  Woonplaats aangewezen  Soesterberg
# 3  16       1015    0622  Vlaardingen  Woonplaats aangewezen  Vlaardingen
# 4   2       1002    0873  Woensdrecht  Woonplaats aangewezen  Ossendrecht
#
#    begindatum einddatumt inonderzoe            documentnu  documentda  \
# 0  2010-04-06       None          N  2010WP00000000000569  2010-04-06
# 1  2010-04-06       None          N  2010WP00000000000569  2010-04-06
# 2  2007-01-16       None          N           AZ/2007/224  2007-01-16
# 3  2007-01-30       None          N         VLD/2007/5652  2007-01-30
# 4  2010-04-06       None          N  2010WP00000000000569  2010-04-06
#
#   indicatie_ aanduiding  aanduidi_1                        key  mutatiedat  \
# ...

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 17 columns):
# id            2500 non-null int64
# identifica    2500 non-null object
# gemcode       2500 non-null object
# gemnaam       2500 non-null object
# status        2500 non-null object
# naam          2500 non-null object
# begindatum    2500 non-null object
# einddatumt    0 non-null object
# inonderzoe    2500 non-null object
# documentnu    2500 non-null object
# documentda    2500 non-null object
# indicatie_    2500 non-null object
# aanduiding    2500 non-null object
# aanduidi_1    2500 non-null int64
# key           2500 non-null object
# mutatiedat    2500 non-null object
# geometry      2500 non-null object
# dtypes: int64(2), object(15)
# memory usage: 332.1+ KB

# %%
f, ax = plt.subplots(1, figsize=(10, 12))
ax = data.plot(ax=ax, edgecolor='white', color='steelblue', linewidth=0.1)
plt.axis('off')
plt.show()

# %% [markdown]
# ### ESRI_PC4_kustlijn_2017R1.shp

# %%
file = '../shapefiles/esri/ESRI_PC4_kustlijn_2017R1-shp/ESRI_PC4_kustlijn_2017R1.shp'
data = gpd.read_file(file)

# %%
data.shape
# Out:
# (4066, 8)

# %%
data.head()
# Out:
#    id  objectid   pc4  aantal_mul  aantal_adr    shape_leng    shape_area  \
# 0   1       1.0  1011           1        7466   5908.190943  1.034025e+06
# 1   2       2.0  1012           1        9261   5489.203939  1.214502e+06
# 2   3       3.0  1013           2       15159  19421.006995  5.075544e+06
# 3   4       4.0  1014           4        1640  15355.645043  2.674418e+06
# 4   5       5.0  1015           1       11274   4732.836386  7.704063e+05
#
#                                             geometry
# 0  POLYGON ((122246.2320000008 487910.1770000011,...
# 1  POLYGON ((121995.0291999988 488243.2021000013,...
# 2  (POLYGON ((120506.2192000002 489494.5513000004...
# 3  (POLYGON ((120390.1125999987 489860.7457000017...
# 4  POLYGON ((120665.6422999986 488535.5, 120668.7...

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4066 entries, 0 to 4065
# Data columns (total 8 columns):
# id            4066 non-null int64
# objectid      4066 non-null float64
# pc4           4066 non-null object
# aantal_mul    4066 non-null int64
# aantal_adr    4066 non-null int64
# shape_leng    4066 non-null float64
# shape_area    4066 non-null float64
# geometry      4066 non-null object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 254.2+ KB

# %%
f, ax = plt.subplots(1, figsize=(10, 12))
ax = data.plot(ax=ax, edgecolor='white', color='steelblue', linewidth=0.1)
plt.axis('off')
plt.show()

# %% [markdown]
# ### CBS Gemeente 2018

# %%
file = '../shapefiles/cbs/2018/Gemeente/gem_2018.shp'
data = gpd.read_file(file)

# %%
data.shape
# Out:
# (468, 30)

# %%
data.head()
# Out:
#   GM_CODE     GM_NAAM WATER   OAD  STED  AANT_INW  AANT_MAN  AANT_VROUW  \
# 0  GM0003  Appingedam   NEE  1051     3     11801      5751        6050
# 1  GM0005       Bedum   NEE   685     4     10475      5235        5240
# 2  GM0009    Ten Boer   NEE   372     5      7292      3616        3676
# 3  GM0010    Delfzijl   NEE   677     4     24864     12475       12389
# 4  GM0014   Groningen   NEE  3456     1    202810    101299      101511
#
#    P_00_14_JR  P_15_24_JR                        ...                          \
# 0          15          10                        ...
# 1          16          11                        ...
# 2          18          12                        ...
# 3          14          11                        ...
# 4          12          24                        ...
#
#    P_HH_M_K  GEM_HH_GR  P_WEST_AL  P_N_W_AL  P_MAROKKO  P_ANT_ARU  P_SURINAM  \
# 0        31        2.1          7         7          0          1          1
# ...

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 30 columns):
# GM_CODE       468 non-null object
# GM_NAAM       467 non-null object
# WATER         468 non-null object
# OAD           468 non-null int64
# STED          468 non-null int64
# AANT_INW      468 non-null int64
# AANT_MAN      468 non-null int64
# AANT_VROUW    468 non-null int64
# P_00_14_JR    468 non-null int64
# P_15_24_JR    468 non-null int64
# P_25_44_JR    468 non-null int64
# P_45_64_JR    468 non-null int64
# P_65_EO_JR    468 non-null int64
# P_ONGEHUWD    468 non-null int64
# P_GEHUWD      468 non-null int64
# P_GESCHEID    468 non-null int64
# P_VERWEDUW    468 non-null int64
# AANTAL_HH     468 non-null int64
# P_EENP_HH     468 non-null int64
# P_HH_Z_K      468 non-null int64
# P_HH_M_K      468 non-null int64
# GEM_HH_GR     468 non-null float64
# P_WEST_AL     468 non-null int64
# P_N_W_AL      468 non-null int64
# P_MAROKKO     468 non-null int64
# ...

# %%
f, ax = plt.subplots(1, figsize=(10, 12))
ax = data.plot(ax=ax, edgecolor='white', color='steelblue', linewidth=0.1)
plt.axis('off')
plt.show()

# %% [markdown]
# ### CBS Wijk 2018

# %%
file = '../shapefiles/cbs/2018/Wijk/Wijk_2018.shp'
data = gpd.read_file(file)

# %%
data.shape
# Out:
# (3174, 33)

# %%
data.head()
# Out:
#     WK_CODE       WK_NAAM GM_CODE     GM_NAAM  IND_WBI WATER   OAD  STED  \
# 0  WK000300       Wijk 00  GM0003  Appingedam        1   NEE  1051     3
# 1  WK000500       Wijk 00  GM0005       Bedum        1   NEE   685     4
# 2  WK000900  Wijk 00 West  GM0009    Ten Boer        1   NEE   442     5
# 3  WK000901  Wijk 01 Oost  GM0009    Ten Boer        1   NEE    72     5
# 4  WK001000  Wijk 00 Stad  GM0010    Delfzijl        1   NEE   906     4
#
#    AANT_INW  AANT_MAN                        ...                          \
# 0     11800      5750                        ...
# 1     10475      5235                        ...
# 2      5945      2910                        ...
# 3      1345       705                        ...
# 4     16885      8370                        ...
#
#    P_HH_M_K  GEM_HH_GR  P_WEST_AL  P_N_W_AL  P_MAROKKO  P_ANT_ARU  P_SURINAM  \
# 0        31        2.1          7         7          0          1          1
# ...

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3174 entries, 0 to 3173
# Data columns (total 33 columns):
# WK_CODE       3174 non-null object
# WK_NAAM       3086 non-null object
# GM_CODE       3174 non-null object
# GM_NAAM       3173 non-null object
# IND_WBI       3174 non-null int64
# WATER         3174 non-null object
# OAD           3174 non-null int64
# STED          3174 non-null int64
# AANT_INW      3174 non-null int64
# AANT_MAN      3174 non-null int64
# AANT_VROUW    3174 non-null int64
# P_00_14_JR    3174 non-null int64
# P_15_24_JR    3174 non-null int64
# P_25_44_JR    3174 non-null int64
# P_45_64_JR    3174 non-null int64
# P_65_EO_JR    3174 non-null int64
# P_ONGEHUWD    3174 non-null int64
# P_GEHUWD      3174 non-null int64
# P_GESCHEID    3174 non-null int64
# P_VERWEDUW    3174 non-null int64
# AANTAL_HH     3174 non-null int64
# P_EENP_HH     3174 non-null int64
# P_HH_Z_K      3174 non-null int64
# P_HH_M_K      3174 non-null int64
# ...

# %%
f, ax = plt.subplots(1, figsize=(10, 12))
ax = data.plot(ax=ax, edgecolor='white', color='steelblue', linewidth=0.1)
plt.axis('off')
plt.show()

# %% [markdown]
# ### CBS Buurt 2018

# %%
file = '../shapefiles/cbs/2018/Buurt/Buurt2018.shp'
data = gpd.read_file(file)

# %%
data.shape
# Out:
# (13404, 36)

# %%
data.head()
# Out:
#       BU_CODE                                      BU_NAAM   WK_CODE GM_CODE  \
# 0  BU00030000                           Appingedam-Centrum  WK000300  GM0003
# 1  BU00030001                              Appingedam-West  WK000300  GM0003
# 2  BU00030002                              Appingedam-Oost  WK000300  GM0003
# 3  BU00030007  Verspreide huizen Damsterdiep en Eemskanaal  WK000300  GM0003
# 4  BU00030008  Verspreide huizen ten zuiden van Eemskanaal  WK000300  GM0003
#
#       GM_NAAM  IND_WBI WATER POSTCODE  DEK_PERC   OAD  \
# 0  Appingedam        1   NEE     9901         1  1195
# 1  Appingedam        1   NEE     9903         5   896
# 2  Appingedam        1   NEE     9902         1  1119
# 3  Appingedam        1   NEE     9903         4   348
# 4  Appingedam        1   NEE     9902         1    74
#
#                          ...                          P_HH_M_K  GEM_HH_GR  \
# 0                        ...                                18        1.7
# ...

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 13404 entries, 0 to 13403
# Data columns (total 36 columns):
# BU_CODE       13404 non-null object
# BU_NAAM       13305 non-null object
# WK_CODE       13404 non-null object
# GM_CODE       13404 non-null object
# GM_NAAM       13403 non-null object
# IND_WBI       13404 non-null int64
# WATER         13404 non-null object
# POSTCODE      13404 non-null object
# DEK_PERC      13404 non-null int64
# OAD           13404 non-null int64
# STED          13404 non-null int64
# AANT_INW      13404 non-null int64
# AANT_MAN      13404 non-null int64
# AANT_VROUW    13404 non-null int64
# P_00_14_JR    13404 non-null int64
# P_15_24_JR    13404 non-null int64
# P_25_44_JR    13404 non-null int64
# P_45_64_JR    13404 non-null int64
# P_65_EO_JR    13404 non-null int64
# P_ONGEHUWD    13404 non-null int64
# P_GEHUWD      13404 non-null int64
# P_GESCHEID    13404 non-null int64
# P_VERWEDUW    13404 non-null int64
# ...

# %%
f, ax = plt.subplots(1, figsize=(10, 12))
ax = data.plot(ax=ax, edgecolor='white', color='steelblue', linewidth=0.1)
plt.axis('off')
plt.show()

# %% [markdown]
# ### BAG woonplaatsen.csv

# %%
data = pd.read_csv('../shapefiles/bag/Postcodes-plaatsen-overheid-nuts-2018/woonplaatsen.csv', sep=';')

# %%
data.shape
# Out:
# (2501, 9)

# %%
data.head()
# Out:
#    wplcode  Woonplaatsnaam  gemcode   Gemeentenaam  Provinciecode  \
# 0     1779   1e Exloërmond     1681  Borger-Odoorn             22
# 1     1780   2e Exloërmond     1681  Borger-Odoorn             22
# 2     1781  2e Valthermond     1681  Borger-Odoorn             22
# 3     1925          Aadorp      141         Almelo             23
# 4     2774      Aagtekerke      717          Veere             29
#
#   Provincienaam Veiligheidsregio         Politie-eenheid Omgevingsdienst
# 0       Drenthe          Drenthe         Noord-Nederland     RUD Drenthe
# 1       Drenthe          Drenthe         Noord-Nederland     RUD Drenthe
# 2       Drenthe          Drenthe         Noord-Nederland     RUD Drenthe
# 3    Overijssel           Twente          Oost-Nederland      RUD Twente
# 4       Zeeland          Zeeland  Zeeland - West-Brabant     RUD Zeeland

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2501 entries, 0 to 2500
# Data columns (total 9 columns):
# wplcode             2501 non-null int64
# Woonplaatsnaam      2501 non-null object
# gemcode             2501 non-null int64
# Gemeentenaam        2501 non-null object
# Provinciecode       2501 non-null int64
# Provincienaam       2501 non-null object
# Veiligheidsregio    2501 non-null object
# Politie-eenheid     2501 non-null object
# Omgevingsdienst     2501 non-null object
# dtypes: int64(3), object(6)
# memory usage: 175.9+ KB

# %% [markdown]
# ### BAG woonplaatsen_pc4.csv

# %%
data = pd.read_csv('../shapefiles/bag/Postcodes-plaatsen-overheid-nuts-2018/woonplaatsen_pc4.csv', sep=';')

# %%
data.shape
# Out:
# (4326, 12)

# %%
data.head()
# Out:
#     pc4  woonplaatscode  woonplaatsnaam  gemeentecode   gemeentenaam  \
# 0  9573            1779   1e Exloërmond          1681  Borger-Odoorn
# 1  9571            1780   2e Exloërmond          1681  Borger-Odoorn
# 2  7877            1781  2e Valthermond          1681  Borger-Odoorn
# 3  7611            1925          Aadorp           141         Almelo
# 4  4363            2774      Aagtekerke           717          Veere
#
#    provinciecode provincienaam veiligheidsregio         politie-eenheid  \
# 0             22       Drenthe          Drenthe         Noord-Nederland
# 1             22       Drenthe          Drenthe         Noord-Nederland
# 2             22       Drenthe          Drenthe         Noord-Nederland
# 3             23    Overijssel           Twente          Oost-Nederland
# 4             29       Zeeland          Zeeland  Zeeland - West-Brabant
#
#   omgevingsdienst drinkwater        netbeheer
# 0     RUD Drenthe        WMD           Enexis
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4326 entries, 0 to 4325
# Data columns (total 12 columns):
# pc4                 4326 non-null int64
# woonplaatscode      4326 non-null int64
# woonplaatsnaam      4326 non-null object
# gemeentecode        4326 non-null int64
# gemeentenaam        4326 non-null object
# provinciecode       4326 non-null int64
# provincienaam       4326 non-null object
# veiligheidsregio    4326 non-null object
# politie-eenheid     4326 non-null object
# omgevingsdienst     4326 non-null object
# drinkwater          4201 non-null object
# netbeheer           4326 non-null object
# dtypes: int64(4), object(8)
# memory usage: 405.6+ KB

# %% [markdown]
# ### BAG woonplaatsen_pc6.csv

# %%
data = pd.read_csv('../shapefiles/bag/Postcodes-plaatsen-overheid-nuts-2018/woonplaatsen_pc6.csv', sep=';')

# %%
data.shape
# Out:
# (458103, 17)

# %%
data.head()
# Out:
#       pc6  woonplaatscode woonplaatsnaam      cbs buurtnaam  \
# 0  9573PA            1779  1e Exloërmond  Eerste Exloërmond
# 1  9573PB            1779  1e Exloërmond  Eerste Exloërmond
# 2  9573PC            1779  1e Exloërmond  Eerste Exloërmond
# 3  9573PD            1779  1e Exloërmond  Eerste Exloërmond
# 4  9573PE            1779  1e Exloërmond  Eerste Exloërmond
#
#                 cbs wijknaam  gemeentecode   gemeentenaam  provinciecode  \
# 0  Wijk 15 Tweede Exloërmond          1681  Borger-Odoorn             22
# 1  Wijk 15 Tweede Exloërmond          1681  Borger-Odoorn             22
# 2  Wijk 15 Tweede Exloërmond          1681  Borger-Odoorn             22
# 3  Wijk 15 Tweede Exloërmond          1681  Borger-Odoorn             22
# 4  Wijk 15 Tweede Exloërmond          1681  Borger-Odoorn             22
#
#   provincienaam waterschapnaam veiligheidsregio  politie-eenheid  \
# 0       Drenthe  Hunze en Aa's          Drenthe  Noord-Nederland
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458103 entries, 0 to 458102
# Data columns (total 17 columns):
# pc6                 458102 non-null object
# woonplaatscode      458103 non-null int64
# woonplaatsnaam      458103 non-null object
# cbs buurtnaam       458009 non-null object
# cbs wijknaam        458009 non-null object
# gemeentecode        458103 non-null int64
# gemeentenaam        458103 non-null object
# provinciecode       458103 non-null int64
# provincienaam       458103 non-null object
# waterschapnaam      457842 non-null object
# veiligheidsregio    458103 non-null object
# politie-eenheid     458103 non-null object
# omgevingsdienst     458103 non-null object
# drinkwater          457962 non-null object
# netbeheer           458100 non-null object
# rdx                 458103 non-null float64
# rdy                 458103 non-null float64
# dtypes: float64(2), int64(3), object(12)
# memory usage: 59.4+ MB
